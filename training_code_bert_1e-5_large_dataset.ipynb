# %%
import os
import random

import numpy as np
import torch
from peft import LoraConfig, TaskType, get_peft_model
from torch import nn


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)


class ModelForSourceCodeEmbedding(nn.Module):
    def __init__(self, model_name, normalize=True):
        super(ModelForSourceCodeEmbedding, self).__init__()
        self.model = AutoModel.from_pretrained(model_name)
        self.normalize = normalize

    def forward(self, **kwargs):
        model_output = self.model(**kwargs)
        embeddings = self.average_pool(model_output, kwargs.get("attention_mask"))
        if self.normalize:
            embeddings = torch.nn.functional.normalize(embeddings, p=2, dim=1)
        return embeddings

    def average_pool(self, model_output, attention_mask):
        token_embeddings = model_output[0]
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
        return (torch.sum(token_embeddings * input_mask_expanded, 1) /
                torch.clamp(input_mask_expanded.sum(1), min=1e-9))

    def __getattr__(self, name: str):
        try:
            return super().__getattr__(name)
        except AttributeError:
            return getattr(self.model, name)

# %%
from transformers import AutoModel, AutoTokenizer


model_name = "microsoft/codebert-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = ModelForSourceCodeEmbedding(model_name)

# %%
peft_config = LoraConfig(
    r=8,
    lora_alpha=16,
    bias="none",
    task_type=TaskType.FEATURE_EXTRACTION,
    target_modules=["key", "query", "value"],
)

model = get_peft_model(model, peft_config)
model.print_trainable_parameters()
# Out:
# trainable params: 442,368 || all params: 125,088,000 || trainable%: 0.3536454336147352

# %%
torch.cuda.empty_cache()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device);

# %%
def get_cosing(q1_embs, q2_embs):
    return torch.sum(q1_embs * q2_embs, axis=1)

def get_loss(cosine_score, labels):
    return torch.mean(torch.square(labels * (1 - cosine_score) + torch.clamp((1 - labels) * cosine_score, min=0.0)))

def threshold(x):
    return 1 if x > 0.5 else 0

# %%
from imblearn.over_sampling import RandomOverSampler
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm


train_cases = ["case-01", "case-02", "case-03", "case-04", "case-05"]
test_cases = ["case-06", "case-07"]

all_cases = ["case-01", "case-02", "case-03", "case-04", "case-05", "case-06", "case-07"]

train_df = pd.DataFrame(data=None, columns=["original_code_file", "secondary_code_file", "label"])
test_df = pd.DataFrame(data=None, columns=["original_code_file", "secondary_code_file", "label"])


def add_to_df(df, original_code_file, secondary_code_file, label):
    df.loc[len(train_df)] = [original_code_file, secondary_code_file, label]

def get_data(df, original_file_path, non_plagiarized_files_paths, plagiarized_files_paths):
    for non_plagiarized_file_path in non_plagiarized_files_paths:
        add_to_df(df, original_file_path, non_plagiarized_file_path, 0)
    for plagiarized_file_path in plagiarized_files_paths:
        add_to_df(df, original_file_path, plagiarized_file_path, 1)

def get_paths(case, mode):
    original_file_path = os.path.join("plagiarism_dataset", case, "original", os.listdir(
        f"plagiarism_dataset/{case}/original")[0])

    # get all other cases:
    non_plagiarized_files_paths_all = []
    if mode == "train":
        for every_other_case in train_cases:
            if every_other_case != case:
                non_plagiarized_files_paths = [os.path.join(dp, f) for dp, dn, filenames in os.walk(os.path.join("plagiarism_dataset", every_other_case)) for f in filenames if os.path.splitext(f)[1] == '.java']
                non_plagiarized_files_paths_all += non_plagiarized_files_paths
    else:
        for every_other_case in all_cases:
            if every_other_case != case:
                non_plagiarized_files_paths = [os.path.join(dp, f) for dp, dn, filenames in os.walk(os.path.join("plagiarism_dataset", every_other_case)) for f in filenames if os.path.splitext(f)[1] == '.java']
                non_plagiarized_files_paths_all += non_plagiarized_files_paths

    #add your own non-plagiarised:
    non_plagiarized_files_paths = [os.path.join(dp, f) for dp, dn, filenames in os.walk(os.path.join(
        "plagiarism_dataset", case, "non-plagiarized")) for f in filenames if os.path.splitext(f)[1] == '.java']
    non_plagiarized_files_paths_all += non_plagiarized_files_paths

    plagiarized_files_paths = [os.path.join(dp, f) for dp, dn, filenames in os.walk(os.path.join(
        "plagiarism_dataset", case, "plagiarized")) for f in filenames if os.path.splitext(f)[1] == '.java']

    return original_file_path, non_plagiarized_files_paths_all, plagiarized_files_paths

# %%
original_file_path, non_plagiarized_files_paths, plagiarized_files_paths = get_paths("case-01", "train")
print("Original")
print(original_file_path)
print("Non-plagiarized")
print(non_plagiarized_files_paths)
print("Plagiarized")
print(plagiarized_files_paths)
# Out:
# Original
# plagiarism_dataset\case-01\original\T1.java
# Non-plagiarized
# ['plagiarism_dataset\\case-02\\non-plagiarized\\01\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\02\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\03\\Nomor2_2451041557A22145B3701B0184109CAB013.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\04\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\05\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\06\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\07\\Main.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\08\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\09\\t02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\10\\Main.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\11\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\12\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\13\\No2.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\14\\Soal2.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\15\\T02.java', 'plagiarism_dataset\\case-02\\original\\T2.java', 'plagiarism_dataset\\case-02\\plagiarized\\L1\\01\\L1.java', 'plagiarism_dataset\\case-02\\plagiarized\\L1\\02\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L1\\03\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L1\\04\\Kasus2.java', 'plagiarism_dataset\\case-02\\plagiarized\\L1\\05\\inputoutput.java', 'plagiarism_dataset\\case-02\\plagiarized\\L1\\06\\inputoutput.java', 'plagiarism_dataset\\case-02\\plagiarized\\L1\\07\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L1\\08\\Kasus2L1.java', 'plagiarism_dataset\\case-02\\plagiarized\\L1\\09\\Level1.java', 'plagiarism_dataset\\case-02\\plagiarized\\L2\\01\\L2.java', 'plagiarism_dataset\\case-02\\plagiarized\\L2\\02\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L2\\03\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L2\\04\\Kasus2.java', 'plagiarism_dataset\\case-02\\plagiarized\\L2\\05\\inputoutput.java', 'plagiarism_dataset\\case-02\\plagiarized\\L2\\06\\inout.java', 'plagiarism_dataset\\case-02\\plagiarized\\L2\\07\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L2\\08\\Kasus2L2.java', 'plagiarism_dataset\\case-02\\plagiarized\\L2\\09\\Level2.java', 'plagiarism_dataset\\case-02\\plagiarized\\L3\\01\\L3.java', 'plagiarism_dataset\\case-02\\plagiarized\\L3\\02\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L3\\03\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L3\\04\\Kasus2.java', 'plagiarism_dataset\\case-02\\plagiarized\\L3\\05\\inputoutput.java', 'plagiarism_dataset\\case-02\\plagiarized\\L3\\06\\inout.java', 'plagiarism_dataset\\case-02\\plagiarized\\L3\\07\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L3\\08\\Kasus2L3.java', 'plagiarism_dataset\\case-02\\plagiarized\\L3\\09\\Level3.java', 'plagiarism_dataset\\case-02\\plagiarized\\L4\\01\\L4.java', 'plagiarism_dataset\\case-02\\plagiarized\\L4\\02\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L4\\03\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L4\\04\\Kasus2.java', 'plagiarism_dataset\\case-02\\plagiarized\\L4\\05\\inputoutput.java', 'plagiarism_dataset\\case-02\\plagiarized\\L4\\06\\inout.java', 'plagiarism_dataset\\case-02\\plagiarized\\L4\\07\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L4\\08\\Kasus2L4.java', 'plagiarism_dataset\\case-02\\plagiarized\\L4\\09\\Level4.java', 'plagiarism_dataset\\case-02\\plagiarized\\L5\\01\\L5.java', 'plagiarism_dataset\\case-02\\plagiarized\\L5\\02\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L5\\03\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L5\\04\\Kasus2.java', 'plagiarism_dataset\\case-02\\plagiarized\\L5\\05\\inputoutput.java', 'plagiarism_dataset\\case-02\\plagiarized\\L5\\06\\inout.java', 'plagiarism_dataset\\case-02\\plagiarized\\L5\\07\\Main.java', 'plagiarism_dataset\\case-02\\plagiarized\\L5\\08\\Kasus2L5.java', 'plagiarism_dataset\\case-02\\plagiarized\\L5\\09\\Level5.java', 'plagiarism_dataset\\case-02\\plagiarized\\L6\\01\\L6.java', 'pla ...
# Plagiarized
# ['plagiarism_dataset\\case-01\\plagiarized\\L1\\01\\L1.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\03\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\04\\T1.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\05\\HelloWorld.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\06\\HelloWorld.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\07\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\08\\Kasus1L1.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\09\\Level1.java', 'plagiarism_dataset\\case-01\\plagiarized\\L2\\01\\L2.java', 'plagiarism_dataset\\case-01\\plagiarized\\L2\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L2\\03\\WelcomeToJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L2\\04\\hellow.java', 'plagiarism_dataset\\case-01\\plagiarized\\L2\\05\\PrintJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\01\\L3.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\03\\HelloWorld.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\04\\hellow.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\05\\Kasus1L3.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\06\\Level3.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\01\\L4.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\03\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\04\\HelloWorld.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\05\\hellow.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\06\\Level4.java', 'plagiarism_dataset\\case-01\\plagiarized\\L5\\01\\L5.java', 'plagiarism_dataset\\case-01\\plagiarized\\L5\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L5\\03\\WelcomeToJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L5\\04\\hellow.java', 'plagiarism_dataset\\case-01\\plagiarized\\L5\\05\\PrintJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\01\\L6.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\03\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\04\\WelcomeToJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\05\\HelloWorld.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\06\\hellow.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\07\\PrintJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\08\\Kasus1L6.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\09\\Level6.java']

# %%
original_file_path, non_plagiarized_files_paths, plagiarized_files_paths = get_paths("case-06", "test")
print("Original")
print(original_file_path)
print("Non-plagiarized")
print(non_plagiarized_files_paths)
print("Plagiarized")
print(plagiarized_files_paths)
# Out:
# Original
# plagiarism_dataset\case-06\original\T6.java
# Non-plagiarized
# ['plagiarism_dataset\\case-01\\non-plagiarized\\01\\T01.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\02\\T01.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\03\\Nomor1_2451041557A22145B3701B0184109CAB013.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\04\\T01.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\05\\T01.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\06\\T01.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\07\\Main.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\08\\T01.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\09\\t01.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\10\\Main.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\11\\T01.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\12\\T01.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\13\\No1.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\14\\Soal1.java', 'plagiarism_dataset\\case-01\\non-plagiarized\\15\\T01.java', 'plagiarism_dataset\\case-01\\original\\T1.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\01\\L1.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\03\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\04\\T1.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\05\\HelloWorld.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\06\\HelloWorld.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\07\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\08\\Kasus1L1.java', 'plagiarism_dataset\\case-01\\plagiarized\\L1\\09\\Level1.java', 'plagiarism_dataset\\case-01\\plagiarized\\L2\\01\\L2.java', 'plagiarism_dataset\\case-01\\plagiarized\\L2\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L2\\03\\WelcomeToJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L2\\04\\hellow.java', 'plagiarism_dataset\\case-01\\plagiarized\\L2\\05\\PrintJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\01\\L3.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\03\\HelloWorld.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\04\\hellow.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\05\\Kasus1L3.java', 'plagiarism_dataset\\case-01\\plagiarized\\L3\\06\\Level3.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\01\\L4.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\03\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\04\\HelloWorld.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\05\\hellow.java', 'plagiarism_dataset\\case-01\\plagiarized\\L4\\06\\Level4.java', 'plagiarism_dataset\\case-01\\plagiarized\\L5\\01\\L5.java', 'plagiarism_dataset\\case-01\\plagiarized\\L5\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L5\\03\\WelcomeToJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L5\\04\\hellow.java', 'plagiarism_dataset\\case-01\\plagiarized\\L5\\05\\PrintJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\01\\L6.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\02\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\03\\Main.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\04\\WelcomeToJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\05\\HelloWorld.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\06\\hellow.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\07\\PrintJava.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\08\\Kasus1L6.java', 'plagiarism_dataset\\case-01\\plagiarized\\L6\\09\\Level6.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\01\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\02\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\03\\Nomor2_2451041557A22145B3701B0184109CAB013.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\04\\T02.java', 'plagiarism_dataset\\case-02\\non-plagiarized\\05\\T02.java', 'plagiarism_dataset ...
# Plagiarized
# ['plagiarism_dataset\\case-06\\plagiarized\\L1\\01\\L1.java', 'plagiarism_dataset\\case-06\\plagiarized\\L1\\02\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L1\\03\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L1\\04\\singlearray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L1\\05\\singlearray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L1\\06\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L1\\07\\Kasus6L1.java', 'plagiarism_dataset\\case-06\\plagiarized\\L1\\08\\Level1.java', 'plagiarism_dataset\\case-06\\plagiarized\\L2\\01\\L2_6.java', 'plagiarism_dataset\\case-06\\plagiarized\\L2\\02\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L2\\03\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L2\\04\\singlearray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L2\\05\\TestSatuArray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L2\\06\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L2\\07\\Kasus6L2.java', 'plagiarism_dataset\\case-06\\plagiarized\\L2\\08\\Level2.java', 'plagiarism_dataset\\case-06\\plagiarized\\L3\\01\\L3.java', 'plagiarism_dataset\\case-06\\plagiarized\\L3\\02\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L3\\03\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L3\\04\\singlearray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L3\\05\\TestSatuArray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L3\\06\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L3\\07\\Kasus6L3.java', 'plagiarism_dataset\\case-06\\plagiarized\\L3\\08\\Level3.java', 'plagiarism_dataset\\case-06\\plagiarized\\L4\\01\\L4.java', 'plagiarism_dataset\\case-06\\plagiarized\\L4\\02\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L4\\03\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L4\\04\\Kasus6.java', 'plagiarism_dataset\\case-06\\plagiarized\\L4\\05\\singlearray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L4\\06\\TestSatuArray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L4\\07\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L4\\08\\Kasus6L4.java', 'plagiarism_dataset\\case-06\\plagiarized\\L4\\09\\Level4.java', 'plagiarism_dataset\\case-06\\plagiarized\\L5\\01\\L5.java', 'plagiarism_dataset\\case-06\\plagiarized\\L5\\02\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L5\\03\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L5\\04\\Kasus6.java', 'plagiarism_dataset\\case-06\\plagiarized\\L5\\05\\singlearray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L5\\06\\TestSatuArray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L5\\07\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L5\\08\\Kasus6L5.java', 'plagiarism_dataset\\case-06\\plagiarized\\L5\\09\\Level5.java', 'plagiarism_dataset\\case-06\\plagiarized\\L6\\01\\L6.java', 'plagiarism_dataset\\case-06\\plagiarized\\L6\\02\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L6\\03\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L6\\04\\Kasus6.java', 'plagiarism_dataset\\case-06\\plagiarized\\L6\\05\\singlearray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L6\\06\\TestSatuArray.java', 'plagiarism_dataset\\case-06\\plagiarized\\L6\\07\\Main.java', 'plagiarism_dataset\\case-06\\plagiarized\\L6\\08\\Kasus6L6.java', 'plagiarism_dataset\\case-06\\plagiarized\\L6\\09\\Level6.java']

# %%
# train-test cycle:
EPOCHS = 10

epochs_losses_train = []
epochs_accuracies_train = []

epochs_losses_test = []
epochs_accuracies_test = []

for epoch in range(EPOCHS):
    train_total_loss = 0
    train_correct = 0
    
    test_total_loss = 0
    test_correct = 0
    
    # train:
    for case in train_cases:
        original_file_path, non_plagiarized_files_paths, plagiarized_files_paths = get_paths(case, "train")
        get_data(train_df, original_file_path, non_plagiarized_files_paths, plagiarized_files_paths)
        train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)
        X_train, X_test, y_train, y_test = train_test_split(train_df[["original_code_file", "secondary_code_file"]], train_df["label"], test_size=0.2, random_state=42)
    
        ros = RandomOverSampler(random_state=42)
        X_train, y_train = ros.fit_resample(X_train, y_train)
        
        X_train = X_train.reset_index(drop=True)
        y_train = y_train.reset_index(drop=True)
        X_test = X_test.reset_index(drop=True)
        y_test = y_test.reset_index(drop=True)
    
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
        loss = nn.CrossEntropyLoss()
        
        total_loss = 0
        correct = 0
        
        model.train()
        bar = tqdm(range(len(X_train)))
        for i in range(len(X_train)):
            original_code = open(X_train["original_code_file"][i], "r").read()
            secondary_code = open(X_train["secondary_code_file"][i], "r").read()
            
            q1 = tokenizer(original_code, return_tensors="pt", max_length=512, truncation=True)
            q2 = tokenizer(secondary_code, return_tensors="pt", max_length=512, truncation=True)
            
            q1 = {k: v.to(device) for k, v in q1.items()}
            q2 = {k: v.to(device) for k, v in q2.items()}
            
            label = torch.tensor([y_train[i]])
            label = label.to(device)
            
            optimizer.zero_grad()
            q1 = model(**q1)
            q2 = model(**q2)
            loss_value = get_loss(get_cosing(q1, q2).to(device), label)
            total_loss += loss_value.item()
            loss_value.backward()
            optimizer.step()
        
            prediction = threshold(get_cosing(q1, q2).item())
            if prediction == label:
                correct += 1
            bar.update(1)
        
        train_total_loss += total_loss / len(X_train)
        train_correct += correct / len(X_train)

    # test:
    for case in test_cases:
        original_file_path, non_plagiarized_files_paths, plagiarized_files_paths = get_paths(case, "test")
        get_data(test_df, original_file_path, non_plagiarized_files_paths, plagiarized_files_paths)
        test_df = test_df.sample(frac=1, random_state=42).reset_index(drop=True)
        X_test, y_test = test_df[["original_code_file", "secondary_code_file"]], test_df["label"]
    
        total_loss = 0
        correct = 0
        
        model.eval()
        bar = tqdm(range(len(X_test)))
        for i in range(len(X_test)):
            original_code = open(X_test["original_code_file"][i], "r").read()
            secondary_code = open(X_test["secondary_code_file"][i], "r").read()
            
            q1 = tokenizer(original_code, return_tensors="pt", max_length=512, truncation=True)
            q2 = tokenizer(secondary_code, return_tensors="pt", max_length=512, truncation=True)
            
            q1 = {k: v.to(device) for k, v in q1.items()}
            q2 = {k: v.to(device) for k, v in q2.items()}
            
            label = torch.tensor([y_test[i]])
            label = label.to(device)
            
            q1 = model(**q1)
            q2 = model(**q2)
            loss_value = get_loss(get_cosing(q1, q2).to(device), label)
            total_loss += loss_value.item()
            
            prediction = threshold(get_cosing(q1, q2).item())
            if prediction == label:
                correct += 1
            bar.update(1)
        
        test_total_loss += total_loss / len(X_test)
        test_correct += correct / len(X_test)
    
    epochs_losses_train.append(train_total_loss / 5)
    print(f"Epoch: {epoch}, Loss train: {train_total_loss / 5}")
    epochs_accuracies_train.append(train_correct / 5)
    print(f"Epoch: {epoch}, Accuracy train: {train_correct / 5}")
    
    epochs_losses_test.append(test_total_loss / 2)
    print(f"Epoch: {epoch}, Loss test: {test_total_loss / 2}")
    epochs_accuracies_test.append(test_correct / 2)
    print(f"Epoch: {epoch}, Accuracy test: {test_correct / 2}")

    torch.save(model, f"models/{epoch + 1}_emb_model")
# Out:
#  49%|████▊     | 114/234 [02:00<02:06,  1.06s/it]
#
#   0%|          | 1/470 [00:00<02:58,  2.63it/s]
#   0%|          | 2/470 [00:00<01:50,  4.25it/s]
#   1%|          | 3/470 [00:00<01:31,  5.08it/s]
#   1%|          | 4/470 [00:00<01:19,  5.90it/s]
#   1%|          | 5/470 [00:00<01:10,  6.56it/s]
#   1%|▏         | 6/470 [00:01<01:09,  6.71it/s]
#   1%|▏         | 7/470 [00:01<01:17,  6.01it/s]
#   2%|▏         | 8/470 [00:01<01:09,  6.67it/s]
#   2%|▏         | 9/470 [00:01<01:15,  6.11it/s]
#   2%|▏         | 10/470 [00:01<01:09,  6.64it/s]
#   2%|▏         | 11/470 [00:01<01:04,  7.10it/s]
#   3%|▎         | 12/470 [00:01<01:01,  7.43it/s]
#   3%|▎         | 13/470 [00:02<00:59,  7.65it/s]
#   3%|▎         | 14/470 [00:02<01:05,  6.94it/s]
#   3%|▎         | 15/470 [00:02<01:14,  6.12it/s]
#   3%|▎         | 16/470 [00:02<01:17,  5.90it/s]
#   4%|▎         | 17/470 [00:02<01:10,  6.46it/s]
#   4%|▍         | 18/470 [00:02<01:03,  7.17it/s]
#   4%|▍         | 19/470 [00:02<00:58,  7.65it/s]
#   4%|▍         | 20/470 [00:03<00:57,  7.79it/s]
#   4%|▍         | 21/470 [00:03<00:58,  7.68it/s]
#   5%|▍         | 22/470 [00:03<01:03,  7.10it/s]
#   5%|▍         | 23/470 [00:03<01:00,  7.38it/s]
#   5%|▌         | 24/470 [00:03<00:57,  7.77it/s]
#   5%|▌         | 25/470 [00:03<00:59,  7.53it/s]
#   6%|▌         | 26/470 [00:03<00:56,  7.81it/s]
#   6%|▌         | 27/470 [00:03<00:56,  7.86it/s]
#   6%|▌         | 28/470 [00:04<00:54,  8.08it/s]
#   6%|▌         | 29/470 [00:04<01:05,  6.75it/s]
#   6%|▋         | 30/470 [00:04<00:59,  7.37it/s]
#   7%|▋         | 31/470 [00:04<00:57,  7.69it/s]
#   7%|▋         | 32/470 [00:04<00:57,  7.63it/s]
#   7%|▋         | 33/470 [00:04<00:53,  8.17it/s]
#   7%|▋         | 34/470 [00:04<00:51,  8.54it/s]
#   7%|▋         | 35/470 [00:05<00:53,  8.09it/s]
#   8%|▊         | 36/470 [00:05<00:51,  8.46it/s]
#   8%|▊         | 37/470 [00:05<00:50,  8.53it/s]
#   8%|▊         | 38/470 [00:05<00:48,  8.87it/s]
#   8%|▊         | 39/470 [00:05<00:56,  7.62it/s]
#   9%|▊         | 40/470 [00:05<00:57,  7.53it/s]
#   9%|▊         | 41/470 [00:05<01:04,  6.64it/s]
#   9%|▉         | 42/470 [00:05<00:59,  7.25it/s]
#   9%|▉         | 43/470 [00:06<00:54,  7.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 61
#      58 loss_value.backward()
#      59 optimizer.step()
# ---> 61 prediction = threshold(get_cosing(q1, q2).item())
#      62 if prediction == label:
#      63     correct += 1
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, EPOCHS + 1), epochs_losses_train, label="Train Loss")
plt.plot(range(1, EPOCHS + 1), epochs_losses_test, label="Val Loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.xticks(range(1, EPOCHS + 1))

plt.show()

# %%
plt.plot(range(1, EPOCHS + 1), epochs_accuracies_train, label="Train Accuracy")
plt.plot(range(1, EPOCHS + 1), epochs_accuracies_test, label="Val Accuracy")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.xticks(range(1, EPOCHS + 1))

plt.show()

# %%
# torch.save(model, "models/code_embedding_model.pth")

# %%
# model = torch.load("code_embedding_model.pth")
# model.eval()

# %%
epochs_losses_test, len(epochs_losses_test)
# Out:
# ([0.23168952763080597,
#   0.26733506098389626,
#   0.2074685085564852,
#   0.2321121586220605,
#   0.1789790496437086,
#   0.18826553775844249,
#   0.07743075477460828,
#   0.06225275509059429,
#   0.0521440793732729,
#   0.290477854224216],
#  10)

# %%
epochs_accuracies_test, len(epochs_accuracies_test)
# Out:
# ([0.25,
#   0.41666666666666663,
#   0.45,
#   0.4642857142857143,
#   0.4722222222222222,
#   0.4772727272727273,
#   1.0,
#   1.0,
#   1.0,
#   0.48684210526315785],
#  10)

# %%
print(f"Max accuracy: {max(epochs_accuracies_test)} at epoch {epochs_accuracies_test.index(max(epochs_accuracies_test)) + 1}")
print(f"Min loss: {min(epochs_losses_test)} at epoch {epochs_losses_test.index(min(epochs_losses_test)) + 1}")
# Out:
# Max accuracy: 1.0 at epoch 7
# Min loss: 0.0521440793732729 at epoch 9
